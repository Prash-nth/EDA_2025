# %% [markdown]
# # EXPLORATORY DATA ANALYSIS(EDA)

# %%
=====================EDA================
1) pandas   : data frame operations
2)numpy    : math operations
3)matplotlib    : plotting or graphs
4) seaborn    :   plotting or graphs
5)plotly     :   plotting or graphs
6)bokhe     :  plotting or graphs

=====================Machine Learning===================
7) sickit-learn(sklearn)   :  For all ML algorithms
8) stats      :   some statistical operations

=====================Deep Learning==================
9)tensorflow   : deep learning models(google)
10)keras       :  deep learning tensorflow as backend
11)pytorch      : deep learning models  
12) opencv     :   image and video operations
13)pillow        :  image operations

=====================Object detection models(transfer learning)==================
14) mobilenet      :     deep learning packages only
15) VGGnet         :     deep learning packages only
16) Resnet         :     deep learning packages only
17) Inceptionv3     :     deep learning packages only
18) YOLO            :     deep learning packages only

====================Natural Languaage Processing=========================
19)    NLTK       :  Natural language tool kit
20) spCy          :  Alternative to NLTK
21)WordCloud      :  Text Representation

=======================NLP word Embedding Models=========================
22)Word2vec    : Google
23)GloVe       : Stanford
24)Fasttext     : Meta

=======================ALLEN NLP(organization)================================
25) NLP applications   :    Pyspark as backend

=======================Optical Character Recognisation(OCR)=====================
    Extarct text from image
26)Tesseract
27)easyocr

===================================BERT=================================
BERT: Bi directional Encoded Representations from tansformers
28) Transformers    :  hugging face(Google)

==================================WebScrapping=======================
29) SQLITE     : connect the database using python
30)Selenium    :
31)Beautiful soup
32)Regex

===========================GenAI and LLM================================
33)Langchain      : To connect all LLm models
34) Gpt     :    openAi
35)gemini:      Google
36) Llama         : Meta
37) Grok      :  XAi
38)BedRock     : Amazon
39) claude Ai  :  Anthropic

=======================Agentic AI =============================
40) Langraph
41)  CrewAI
42) Phidata
43) Autogen

=========================API creation ==========================
44) Flask
45) fast API
46) gradio
47) Django

=======================webApplication ===========================
48) Streamlit

===========================Model deployment ===========================
49)mlflow
50)Kubeflow

======================== Cloud AI ==================================
51) Azure Cognitive services
52)Azure ML studio
53)GCP vertexAI
54)AWS Sagemaker

========================Extra =========================
55) random
56) time
57) math
58) loggings
59) warnings
60) date

# %% [markdown]
# **Step-1: Import packages**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Step-2:Create a Dataframe using list**

# %%
names=['ram','shyam','prem']
pd.DataFrame(names)
# Out:
#        0
# 0    ram
# 1  shyam
# 2   prem

# %%
names=['ram','shyam','prem']
age=[20,30,40]
pd.DataFrame(names,age)
# Out:
#         0
# 20    ram
# 30  shyam
# 40   prem

# %%
names=['ram','shyam','prem']
age=[20,30,40]
pd.DataFrame(zip(names,age))
# Out:
#        0   1
# 0    ram  20
# 1  shyam  30
# 2   prem  40

# %%
names=['ram','shyam','prem']
age=[20,30,40]
city=['hyd','bnglr','pune']
pd.DataFrame(zip(names,age,city))
# Out:
#        0   1      2
# 0    ram  20    hyd
# 1  shyam  30  bnglr
# 2   prem  40   pune

# %% [markdown]
# **Step-3:Add the column**

# %%
names=['ram','shyam','prem']
pd.DataFrame(names,columns=['Names'])
# Out:
#    Names
# 0    ram
# 1  shyam
# 2   prem

# %%
names=['ram','shyam','prem']
age=[20,30,40]
city=['hyd','bnglr','pune']
pd.DataFrame(zip(names,age,city),columns=['Names','Age','City'])
# Out:
#    Names  Age   City
# 0    ram   20    hyd
# 1  shyam   30  bnglr
# 2   prem   40   pune

# %%
**Step-4:Modify the index**

# %%
names=['ram','shyam','prem']
age=[20,30,40]
city=['hyd','bnglr','pune']
df1=pd.DataFrame(zip(names,age,city),index=['A','B','C'],columns=['Names','Age','City'])

# %%
df1
# Out:
#    Names  Age   City
# a    ram   20    hyd
# b  shyam   30  bnglr
# c   prem   40   pune

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# - index length should match with no. of rows
# - columns length should be match with no. of cols

# %% [markdown]
# **Step-4:Create a Dataframe using Dictonary**

# %%
names=['ram','shyam','prem']
age=[20,30,40]
city=['hyd','bnglr','pune']

d={'Names':['Ram','Prem','Shyam'],
    'Age':[20,30,40],
     'City':['hyd','pune','bnglr']}
pd.DataFrame(d,index=['A','B','C'])

#Keys behave as colums
# No need to mention explicitly
# Out:
#    Names  Age   City
# A    Ram   20    hyd
# B   Prem   30   pune
# C  Shyam   40  bnglr

# %% [markdown]
# **Step-6:Create a Scalar Quantity using Dictonry(Single values)**

# %%
d={'Names':'Ram',
    'Age':20,
     'City':'hyd'}
pd.DataFrame(d,index=[1])
# Out:
#   Names  Age City
# 1   Ram   20  hyd

# %% [markdown]
# **Step-7:Data quick checks**
# - shape
# - size
# - len
# - columns
# - dtypes

# %%
df1.shape
# Out:
# (3, 3)

# %%
df1.size
# Out:
# 9

# %%
df1.len
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9008\1757538638.py in ?()
# ----> 1 df1.length
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'length'

# %%
df1.columns
# Out:
# Index(['Names', 'Age', 'City'], dtype='object')

# %%
df1.dtypes
# Out:
# Names    object
# Age       int64
# City     object
# dtype: object

# %% [markdown]
# **Step-8:Add the data to Empty dataframe**

# %%
d1=pd.DataFrame()
d1['Names']=['Ram','Prem','Shyam']
d1['Age']=[12,14,15]
d1
# Out:
#    Names  Age
# 0    Ram   12
# 1   Prem   14
# 2  Shyam   15

# %% [markdown]
# **Ste-9:Add data to Already existed dataframe**
# - we want to add marks to already existed data fram(df1)

# %%
df1['Marks']=[100,99,80]
df1
# Out:
#    Names  Age   City  Marks
# A    ram   20    hyd    100
# B  shyam   30  bnglr     99
# C   prem   40   pune     80

# %% [markdown]
# **Step-10:Updating the column values**
# - if u wnt to add new column to empty dataframe..
# - or if u want to add new column to existed DF
# - or if u want to modify the adat of a specific column
# - syntax is asame

# %%
df1
# Out:
#    Names  Age   City  Marks
# a    ram   20    hyd    100
# b  shyam   30  bnglr     99
# c   prem   40   pune     80

# %%
df1['City']=['mumbai','chennai','agra']
df1['city']=['mumbai','chennai','agra']
df1
# Out:
#    Names  Age     City  Marks     city
# a    ram   20   mumbai    100   mumbai
# b  shyam   30  chennai     99  chennai
# c   prem   40     agra     80     agra

# %% [markdown]
# **Step-11:How to drop the specific column**
# - by default axis=0 represents index
# - if u provide the column change axis=1
# - inplace =True ..then dataframe will be saved

# %%
df1.drop('city',axis=1,inplace=True)

# %%
df1
# Out:
#    Names  Age     City  Marks
# a    ram   20   mumbai    100
# b  shyam   30  chennai     99
# c   prem   40     agra     80

# %%
df1['age']=[20,30,40]
df1
# Out:
#    Names  Age   City  age
# A    ram   20    hyd   20
# B  shyam   30  bnglr   30
# C   prem   40   pune   40

# %%
df1.drop(columns='age',inplace=True)

# %%
df1
# Out:
#    Names  Age   City
# A    ram   20    hyd
# B  shyam   30  bnglr
# C   prem   40   pune

# %%
df1['age']=[20,30,40]
df1['city']=['raipole','ibp','secbad']
df1
# Out:
#    Names  Age   City  age     city
# A    ram   20    hyd   20  raipole
# B  shyam   30  bnglr   30      ibp
# C   prem   40   pune   40   secbad

# %%
df1.drop(columns=['city','age'])
# Out:
#    Names  Age   City
# A    ram   20    hyd
# B  shyam   30  bnglr
# C   prem   40   pune

# %%
df1.drop(['A'])
# Out:
#    Names  Age   City  age    city
# B  shyam   30  bnglr   30     ibp
# C   prem   40   pune   40  secbad

# %% [markdown]
# **Step-12:Rename the column**
# - create a dictionary first
# - key as old name and value as new name

# %%
dict1={'Age':'Living Age'}
df1.rename(dict1,axis=1)
# Out:
#    Names  Living Age   City  age     city
# A    ram          20    hyd   20  raipole
# B  shyam          30  bnglr   30      ibp
# C   prem          40   pune   40   secbad

# %%
dict1={'City':'Place'}
df1.rename(columns=dict1)
# Out:
#    Names  Age  Place  age     city
# A    ram   20    hyd   20  raipole
# B  shyam   30  bnglr   30      ibp
# C   prem   40   pune   40   secbad

# %%
df1.drop(['age','city'],axis=1,inplace=True)

# %%
df1
# Out:
#    Names  Age   City  Marks
# A    ram   20    hyd    100
# B  shyam   30  bnglr     99
# C   prem   40   pune     80

# %% [markdown]
# **Step-13:Add a new row**

# %%
df1.loc['D']=['sita',24,'agra',56]
df1
# Out:
#    Names  Age   City  Marks
# A    ram   20    hyd    100
# B  shyam   30  bnglr     99
# C   prem   40   pune     80
# D   sita   24   agra     56

# %%
df1.drop(labels='D',inplace)
# Out:
#    Names  Age   City  Marks
# A    ram   20    hyd    100
# B  shyam   30  bnglr     99
# C   prem   40   pune     80

# %% [markdown]
# **Step-14:Save the dataframe**

# %%
df1
# Out:
#    Names  Age   City  Marks
# A    ram   20    hyd    100
# B  shyam   30  bnglr     99
# C   prem   40   pune     80
# D   sita   24   agra     56

# %%
df1.to_csv('owndata.csv')

# %% [markdown]
# **Step-15:Read the dataframe**

# %%
pd.read_csv('owndata.csv')
# Out:
#   Unnamed: 0  Names  Age   City  Marks
# 0          A    ram   20    hyd    100
# 1          B  shyam   30  bnglr     99
# 2          C   prem   40   pune     80
# 3          D   sita   24   agra     56

# %%
df1.to_csv('owndata1.csv',index=False)

# %%
pd.read_csv('owndata1.csv')
# Out:
#    Names  Age   City  Marks
# 0    ram   20    hyd    100
# 1  shyam   30  bnglr     99
# 2   prem   40   pune     80
# 3   sita   24   agra     56

# %%
df1.to_excel('owndata2.xlsx',index=False)
pd.read_excel('owndata2.xlsx')
# Out:
#    Names  Age   City  Marks
# 0    ram   20    hyd    100
# 1  shyam   30  bnglr     99
# 2   prem   40   pune     80
# 3   sita   24   agra     56

# %%
pd.read_csv(r"C:\Users\achin\Downloads\DataSets(Nareshit)\bank.csv")
# Out:
#      age;"job";"marital";"education";"default";"balance";"housing";"loan";"contact";"day";"month";"duration";"campaign";"pdays";"previous";"poutcome";"y"
# 0     30;"unemployed";"married";"primary";"no";1787;...
# 1     33;"services";"married";"secondary";"no";4789;...
# 2     35;"management";"single";"tertiary";"no";1350;...
# 3     30;"management";"married";"tertiary";"no";1476...
# 4     59;"blue-collar";"married";"secondary";"no";0;...
# ...                                                 ...
# 4516  33;"services";"married";"secondary";"no";-333;...
# 4517  57;"self-employed";"married";"tertiary";"yes";...
# 4518  57;"technician";"married";"secondary";"no";295...
# 4519  28;"blue-collar";"married";"secondary";"no";11...
# 4520  44;"entrepreneur";"single";"tertiary";"no";113...
#
# [4521 rows x 1 columns]

# %%
pd.read_csv(r"C:\Users\achin\Downloads\DataSets(Nareshit)\Visadataset.csv")
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...
